# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 40

# 1. 데이터셋 생성하기
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# 데이터 분리
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# 데이터셋 생성
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# 데이터셋 전처리
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

x_train = np.squeeze(x_train)
x_val = np.squeeze(x_val)
x_test = np.squeeze(x_test)

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(32,input_dim=40,activation="relu"))
model.add(Dropout(0.3))
for i in range(2):
    model.add(Dense(32,activation="relu"))
    model.add(Dropout(0.3))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='adagrad')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=200, batch_size=32, validation_data=(x_val, y_val))

# 5. 학습과정 살펴보기
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylim(0.0, 0.15)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
          
# 6. 모델 평가하기
trainScore = model.evaluate(x_train, y_train, verbose=0)
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val, verbose=0)
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, verbose=0)
print('Test Score: ', testScore)

# 7. 모델 사용하기
look_ahead = 250
xhat = x_test[0, None]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(xhat, batch_size=32)
    predictions[i] = prediction
    xhat = np.hstack([xhat[:,1:],prediction])
    
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 24/24 [==============================] - 4s 115ms/step - loss: 0.3600 - val_loss: 0.1975
# Epoch 2/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.3031 - val_loss: 0.1720
# Epoch 3/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2990 - val_loss: 0.1605
# Epoch 4/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.2414 - val_loss: 0.1451
# Epoch 5/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.2474 - val_loss: 0.1361
# Epoch 6/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.2191 - val_loss: 0.1254
# Epoch 7/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.2252 - val_loss: 0.1194
# Epoch 8/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1854 - val_loss: 0.1093
# Epoch 9/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1939 - val_loss: 0.1032
# Epoch 10/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1632 - val_loss: 0.0939
# Epoch 11/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1733 - val_loss: 0.0879
# Epoch 12/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1571 - val_loss: 0.0809
# Epoch 13/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1500 - val_loss: 0.0772
# Epoch 14/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1679 - val_loss: 0.0735
# Epoch 15/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.1565 - val_loss: 0.0687
# Epoch 16/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.1689 - val_loss: 0.0632
# Epoch 17/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.1549 - val_loss: 0.0581
# Epoch 18/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.
200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0573 - val_loss: 0.0149
# Epoch 144/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0597 - val_loss: 0.0150
# Epoch 145/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0543 - val_loss: 0.0147
# Epoch 146/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0483 - val_loss: 0.0149
# Epoch 147/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0544 - val_loss: 0.0149
# Epoch 148/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0537 - val_loss: 0.0149
# Epoch 149/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0452 - val_loss: 0.0147
# Epoch 150/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0532 - val_loss: 0.0141
# Epoch 151/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0620 - val_loss: 0.0139
# Epoch 152/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0537 - val_loss: 0.0138
# Epoch 153/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0535 - val_loss: 0.0139
# Epoch 154/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0524 - val_loss: 0.0141
# Epoch 155/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0463 - val_loss: 0.0141
# Epoch 156/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0510 - val_loss: 0.0137
# Epoch 157/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0562 - val_loss: 0.0136
# Epoch 158/200
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0529 - val_loss: 0.0145
# Epoch 159/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0484 - val_loss: 0.0144
# Epoch 160/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0545 - val_loss: 0.0145
# Epoch 161/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0528 - val_loss: 0.0145
# Epoch 162/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0479 - val_loss: 0.0143
# Epoch 163/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0600 - val_loss: 0.0141
# Epoch 164/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0510 - val_loss: 0.0141
# Epoch 165/200
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0484 - val_loss: 0.0135
# Epoch 166/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0573 - val_loss: 0.0134
# Epoch 167/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0502 - val_loss: 0.0134
# Epoch 168/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0534 - val_loss: 0.0138
# Epoch 169/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0523 - val_loss: 0.0137
# Epoch 170/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0527 - val_loss: 0.0140
# Epoch 171/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0490 - val_loss: 0.0143
# Epoch 172/200
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0570 - val_loss: 0.0142
# Epoch 173/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0492 - val_loss: 0.0136
# Epoch 174/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0492 - val_loss: 0.0136
# Epoch 175/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0469 - val_loss: 0.0135
# Epoch 176/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0625 - val_loss: 0.0137
# Epoch 177/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0517 - val_loss: 0.0137
# Epoch 178/200
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0528 - val_loss: 0.0137
# Epoch 179/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0507 - val_loss: 0.0131
# Epoch 180/200
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0586 - val_loss: 0.0131
# Epoch 181/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0520 - val_loss: 0.0132
# Epoch 182/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0514 - val_loss: 0.0133
# Epoch 183/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0518 - val_loss: 0.0137
# Epoch 184/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0412 - val_loss: 0.0141
# Epoch 185/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0493 - val_loss: 0.0138
# Epoch 186/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0526 - val_loss: 0.0130
# Epoch 187/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0460 - val_loss: 0.0134
# Epoch 188/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0418 - val_loss: 0.0137
# Epoch 189/200
# 24/24 [==============================] - ETA: 0s - loss: 0.046 - 0s 8ms/step - loss: 0.0469 - val_loss: 0.0135
# Epoch 190/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0448 - val_loss: 0.0136
# Epoch 191/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0418 - val_loss: 0.0134
# Epoch 192/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0594 - val_loss: 0.0137
# Epoch 193/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0480 - val_loss: 0.0132
# Epoch 194/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0518 - val_loss: 0.0131
# Epoch 195/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0493 - val_loss: 0.0128
# Epoch 196/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0495 - val_loss: 0.0124
# Epoch 197/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0463 - val_loss: 0.0126
# Epoch 198/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0434 - val_loss: 0.0130
# Epoch 199/200
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0484 - val_loss: 0.0125
# Epoch 200/200
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0474 - val_loss: 0.0124
# Train Score:  0.012614715844392776
# Validataion Score:  0.012430272065103054
# Test Score:  0.012430272065103054

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 40

# 1. 데이터셋 생성하기
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# 데이터 분리
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# 데이터셋 생성
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# 데이터셋 전처리
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# 2. 모델 구성하기
model = Sequential()
model.add(LSTM(32, input_shape=(None, 1)))
model.add(Dropout(0.3))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='adam')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=200, batch_size=32, validation_data=(x_val, y_val))

# 5. 학습과정 살펴보기
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylim(0.0, 0.15)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# 6. 모델 평가하기
trainScore = model.evaluate(x_train, y_train, verbose=0)
model.reset_states()
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val, verbose=0)
model.reset_states()
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, verbose=0)
model.reset_states()
print('Test Score: ', testScore)

# 7. 모델 사용하기
look_ahead = 250
xhat = x_test[0]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size=1)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:],prediction])
    
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 24/24 [==============================] - 5s 60ms/step - loss: 0.3679 - val_loss: 0.0417
# Epoch 2/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0482 - val_loss: 0.0228
# Epoch 3/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0314 - val_loss: 0.0117
# Epoch 4/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0184 - val_loss: 0.0046
# Epoch 5/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0144 - val_loss: 0.0013
# Epoch 6/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0107 - val_loss: 9.4904e-04
# Epoch 7/200
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0077 - val_loss: 5.6320e-04
# Epoch 8/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0082 - val_loss: 2.8485e-04
# Epoch 9/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0080 - val_loss: 5.9596e-04
# Epoch 10/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0058 - val_loss: 7.7637e-04
# Epoch 11/200
# 24/24 [==============================] - 0s 19ms/step - loss: 0.0064 - val_loss: 3.0740e-04
# Epoch 12/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0068 - val_loss: 2.0096e-04
# Epoch 13/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0079 - val_loss: 3.4691e-04
# Epoch 14/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 2.1523e-04
# Epoch 15/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 4.5506e-04
# Epoch 16/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0061 - val_loss: 3.7149e-04
# Epoch 17/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0055 - val_loss: 4.3920e-04
# Epoch 18/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0053 - val_loss: 3.0569e-04
# Epoch 19/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 3.5625e-04
# Epoch 20/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0060 - val_loss: 2.5159e-04
# Epoch 21/200
# 24/24 [==============================] - 0s 18ms/step - loss: 0.
200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0024 - val_loss: 1.6080e-04
# Epoch 143/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 2.2949e-04
# Epoch 144/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 7.5923e-05
# Epoch 145/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 5.1632e-05
# Epoch 146/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 5.8021e-05
# Epoch 147/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 1.2116e-04
# Epoch 148/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 1.0054e-04
# Epoch 149/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 6.0465e-05
# Epoch 150/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 3.9832e-04
# Epoch 151/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 3.8627e-05
# Epoch 152/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 2.1617e-05
# Epoch 153/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 1.1743e-05
# Epoch 154/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 4.6897e-05
# Epoch 155/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 4.1535e-04
# Epoch 156/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 1.3943e-04
# Epoch 157/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 2.0757e-04
# Epoch 158/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 3.3557e-05
# Epoch 159/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 8.2248e-05
# Epoch 160/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 4.3466e-04
# Epoch 161/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 6.9978e-05
# Epoch 162/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 1.4986e-05
# Epoch 163/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 2.9442e-04
# Epoch 164/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 8.1436e-05
# Epoch 165/200
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0019 - val_loss: 1.1190e-04
# Epoch 166/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 6.9085e-05
# Epoch 167/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 2.5835e-04
# Epoch 168/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 1.6106e-04
# Epoch 169/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 6.0767e-06
# Epoch 170/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 2.6494e-04
# Epoch 171/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 1.5823e-04
# Epoch 172/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 4.5537e-04
# Epoch 173/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 4.4803e-05
# Epoch 174/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 3.5480e-05
# Epoch 175/200
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 1.2151e-04
# Epoch 176/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 8.7345e-05
# Epoch 177/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0020 - val_loss: 1.9679e-05
# Epoch 178/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 9.3642e-05
# Epoch 179/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 3.6410e-04
# Epoch 180/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 9.7569e-05
# Epoch 181/200
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 1.0436e-04
# Epoch 182/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 9.2583e-05
# Epoch 183/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 1.3590e-04
# Epoch 184/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 6.4692e-05
# Epoch 185/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 5.2545e-05
# Epoch 186/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0017 - val_loss: 4.5019e-05
# Epoch 187/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0016 - val_loss: 6.6989e-05
# Epoch 188/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 2.2067e-04
# Epoch 189/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 4.0845e-05
# Epoch 190/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 2.7288e-05
# Epoch 191/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 1.6601e-04
# Epoch 192/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 8.4900e-05
# Epoch 193/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 6.9029e-05
# Epoch 194/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 3.9445e-04
# Epoch 195/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 3.4881e-05
# Epoch 196/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0019 - val_loss: 3.0361e-05
# Epoch 197/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 1.2630e-04
# Epoch 198/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 6.4609e-05
# Epoch 199/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 4.5417e-04
# Epoch 200/200
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 7.8572e-05
# Train Score:  7.937482587294653e-05
# Validataion Score:  7.85721858846955e-05
# Test Score:  7.85721858846955e-05

# %%
# 0. 사용할 패키지 불러오기
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

class CustomHistory(keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

look_back = 40

# 1. 데이터셋 생성하기
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# 데이터 분리
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# 데이터셋 생성
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# 데이터셋 전처리
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# 2. 모델 구성하기
model = Sequential()
model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='adam')

# 4. 모델 학습시키기
custom_hist = CustomHistory()
custom_hist.init()

for i in range(200):
    model.fit(x_train, y_train, epochs=1, batch_size=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val, y_val))
    model.reset_states()

# 5. 학습과정 살펴보기
plt.plot(custom_hist.train_loss)
plt.plot(custom_hist.val_loss)
plt.ylim(0.0, 0.15)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# 6. 모델 평가하기
trainScore = model.evaluate(x_train, y_train, batch_size=1, verbose=0)
model.reset_states()
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val, batch_size=1, verbose=0)
model.reset_states()
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, batch_size=1, verbose=0)
model.reset_states()
print('Test Score: ', testScore)

# 7. 모델 사용하기
look_ahead = 250
xhat = x_test[0]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size=1)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:],prediction])
    
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
# Out:
# 760/760 [==============================] - 10s 9ms/step - loss: 0.0243 - val_loss: 0.0041
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0077 - val_loss: 0.0016
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0060 - val_loss: 0.0027
# 760/760 [==============================] - 6s 9ms/step - loss: 0.0054 - val_loss: 0.0039
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0043 - val_loss: 8.9884e-04
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0039 - val_loss: 0.0018
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0041 - val_loss: 0.0044
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0041 - val_loss: 0.0223
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0035 - val_loss: 0.0031
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0038 - val_loss: 0.0034
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0031 - val_loss: 0.0107
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0034 - val_loss: 0.0081
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0033 - val_loss: 0.0015
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0036 - val_loss: 0.0025
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0027 - val_loss: 0.0013
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0037 - val_loss: 0.0018
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0029 - val_loss: 8.4106e-04
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0029 - val_loss: 0.0012
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0025 - val_loss: 6.3011e-04
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0022 - val_loss: 0.0017
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0025 - val_loss: 7.6392e-04
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0027 - val_loss: 4.4669e-04
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0026 - val_loss: 0.0020
# 760/760 [==============================] - 6s 9ms/step - loss: 0.0030 - val_loss: 0.0016
# 760/760 [==============================] - 7s 9ms/step - loss: 0.0027 - val_loss: 0.0014
# 760/760 [==============================] - 6s 9ms/step - loss: 0.0025 - val_loss: 0.0013
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0024 - val_loss: 0.0013
# 760/760 [==============================] - 6s 8ms/step - loss: 0.
-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0020 - val_loss: 4.4622e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0019 - val_loss: 4.4337e-04
# 760/760 [==============================] - 5s 7ms/step - loss: 0.0019 - val_loss: 1.0840e-04
# 760/760 [==============================] - 6s 7ms/step - loss: 0.0018 - val_loss: 1.1866e-04
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0022 - val_loss: 2.3184e-04
# 760/760 [==============================] - 6s 8ms/step - loss: 0.0020 - val_loss: 1.1662e-04
# 760/760 [==============================] - 6s 7ms/step - loss: 0.0021 - val_loss: 2.2056e-04
# Train Score:  0.0002301585191162303
# Validataion Score:  0.0002205684722866863
# Test Score:  0.0002205684722866863

# %%
# 0. 사용할 패키지 불러오기
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

class CustomHistory(keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

look_back = 40

# 1. 데이터셋 생성하기
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# 데이터 분리
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# 데이터셋 생성
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# 데이터셋 전처리
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# 2. 모델 구성하기
model = Sequential()
for i in range(2):
    model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True, return_sequences=True))
    model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='adam')

# 4. 모델 학습시키기
custom_hist = CustomHistory()
custom_hist.init()

for i in range(200):
    model.fit(x_train, y_train, epochs=1, batch_size=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val, y_val))
    model.reset_states()

# 5. 학습과정 살펴보기
plt.plot(custom_hist.train_loss)
plt.plot(custom_hist.val_loss)
plt.ylim(0.0, 0.15)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# 6. 모델 평가하기
trainScore = model.evaluate(x_train, y_train, batch_size=1, verbose=0)
model.reset_states()
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val, batch_size=1, verbose=0)
model.reset_states()
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, batch_size=1, verbose=0)
model.reset_states()
print('Test Score: ', testScore)

# 7. 모델 사용하기
look_ahead = 250
xhat = x_test[0]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size=1)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:],prediction])
    
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
# Out:
# 760/760 [==============================] - 19s 21ms/step - loss: 0.0449 - val_loss: 0.0530
# 760/760 [==============================] - 14s 19ms/step - loss: 0.