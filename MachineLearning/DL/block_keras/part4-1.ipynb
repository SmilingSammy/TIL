# %%
import numpy as np

# 데이터셋 생성
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 데이터셋 확인
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(x_train, y_train, 'ro')
plt.plot(x_test, y_test, 'bo')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from sklearn.metrics import mean_squared_error
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

x_train = x_train.reshape(1000,)
y_train = y_train.reshape(1000,)
x_test = x_test.reshape(100,)
y_test = y_test.reshape(100,)

# 2. 모델 구성하기
w = np.cov(x_train, y_train, bias=1)[0,1] / np.var(x_train)
b = np.average(y_train) - w * np.average(x_train)

print(w, b)

# 3. 모델 평가하기
y_predict = w * x_test + b
mse = mean_squared_error(y_test, y_predict)
print('mse : ' + str(mse))
# Out:
# 1.9978980758754172 0.17082875939773445
# mse : 0.00783629117358419

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(1, input_dim=1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)
w, b = model.get_weights()
print(w, b)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 16/16 [==============================] - 0s 682us/step - loss: 0.2447
# Epoch 2/50
# 16/16 [==============================] - 0s 685us/step - loss: 0.2189
# Epoch 3/50
# 16/16 [==============================] - 0s 797us/step - loss: 0.1931
# Epoch 4/50
# 16/16 [==============================] - 0s 848us/step - loss: 0.1817
# Epoch 5/50
# 16/16 [==============================] - 0s 853us/step - loss: 0.1522
# Epoch 6/50
# 16/16 [==============================] - 0s 841us/step - loss: 0.1315
# Epoch 7/50
# 16/16 [==============================] - 0s 840us/step - loss: 0.1171
# Epoch 8/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1088
# Epoch 9/50
# 16/16 [==============================] - 0s 688us/step - loss: 0.0971
# Epoch 10/50
# 16/16 [==============================] - 0s 688us/step - loss: 0.0812
# Epoch 11/50
# 16/16 [==============================] - 0s 770us/step - loss: 0.0720
# Epoch 12/50
# 16/16 [==============================] - 0s 822us/step - loss: 0.0606
# Epoch 13/50
# 16/16 [==============================] - 0s 887us/step - loss: 0.0510
# Epoch 14/50
# 16/16 [==============================] - 0s 867us/step - loss: 0.0403
# Epoch 15/50
# 16/16 [==============================] - 0s 750us/step - loss: 0.0369
# Epoch 16/50
# 16/16 [==============================] - 0s 732us/step - loss: 0.0296
# Epoch 17/50
# 16/16 [==============================] - 0s 784us/step - loss: 0.0237
# Epoch 18/50
# 16/16 [==============================] - 0s 765us/step - loss: 0.0211
# Epoch 19/50
# 16/16 [==============================] - 0s 828us/step - loss: 0.0184
# Epoch 20/50
# 16/16 [==============================] - 0s 864us/step - loss: 0.0165
# Epoch 21/50
# 16/16 [==============================] - 0s 835us/step - loss: 0.0146
# Epoch 22/50
# 16/16 [==============================] - 0s 824us/step - loss: 0.0138
# Epoch 23/50
# 16/16 [==============================] - 0s 905us/step - loss: 0.0139
# Epoch 24/50
# 16/16 [==============================] - 0s 797us/step - loss: 0.0134
# Epoch 25/50
# 16/16 [==============================] - 0s 744us/step - loss: 0.0136
# Epoch 26/50
# 16/16 [==============================] - 0s 747us/step - loss: 0.0125
# Epoch 27/50
# 16/16 [==============================] - 0s 796us/step - loss: 0.0120
# Epoch 28/50
# 16/16 [==============================] - 0s 861us/step - loss: 0.0124
# Epoch 29/50
# 16/16 [==============================] - 0s 879us/step - loss: 0.0116
# Epoch 30/50
# 16/16 [==============================] - 0s 858us/step - loss: 0.0107
# Epoch 31/50
# 16/16 [==============================] - 0s 863us/step - loss: 0.0112
# Epoch 32/50
# 16/16 [==============================] - 0s 858us/step - loss: 0.0110
# Epoch 33/50
# 16/16 [==============================] - 0s 785us/step - loss: 0.0105
# Epoch 34/50
# 16/16 [==============================] - 0s 758us/step - loss: 0.0103
# Epoch 35/50
# 16/16 [==============================] - 0s 804us/step - loss: 0.0101
# Epoch 36/50
# 16/16 [==============================] - 0s 882us/step - loss: 0.0099
# Epoch 37/50
# 16/16 [==============================] - 0s 873us/step - loss: 0.0098
# Epoch 38/50
# 16/16 [==============================] - 0s 897us/step - loss: 0.0094
# Epoch 39/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 40/50
# 16/16 [==============================] - 0s 965us/step - loss: 0.0100
# Epoch 41/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 42/50
# 16/16 [==============================] - 0s 882us/step - loss: 0.0095
# Epoch 43/50
# 16/16 [==============================] - 0s 836us/step - loss: 0.0095
# Epoch 44/50
# 16/16 [==============================] - 0s 857us/step - loss: 0.0094
# Epoch 45/50
# 16/16 [==============================] - 0s 794us/step - loss: 0.0095
# Epoch 46/50
# 16/16 [==============================] - 0s 837us/step - loss: 0.0093
# Epoch 47/50
# 16/16 [==============================] - 0s 953us/step - loss: 0.0098
# Epoch 48/50
# 16/16 [==============================] - 0s 896us/step - loss: 0.0091
# Epoch 49/50
# 16/16 [==============================] - 0s 898us/step - loss: 0.0094
# Epoch 50/50
# 16/16 [==============================] - 0s 833us/step - loss: 0.0094
# [[1.9519806]] [0.1911203]
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0100
# loss : 0.01001136377453804

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 16/16 [==============================] - 0s 822us/step - loss: 1.2484
# Epoch 2/50
# 16/16 [==============================] - 0s 921us/step - loss: 0.8025
# Epoch 3/50
# 16/16 [==============================] - 0s 990us/step - loss: 0.4883
# Epoch 4/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2830
# Epoch 5/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1505
# Epoch 6/50
# 16/16 [==============================] - 0s 989us/step - loss: 0.0812
# Epoch 7/50
# 16/16 [==============================] - 0s 933us/step - loss: 0.0551
# Epoch 8/50
# 16/16 [==============================] - 0s 951us/step - loss: 0.0444
# Epoch 9/50
# 16/16 [==============================] - 0s 894us/step - loss: 0.0334
# Epoch 10/50
# 16/16 [==============================] - 0s 941us/step - loss: 0.0226
# Epoch 11/50
# 16/16 [==============================] - 0s 883us/step - loss: 0.0148
# Epoch 12/50
# 16/16 [==============================] - 0s 936us/step - loss: 0.0115
# Epoch 13/50
# 16/16 [==============================] - 0s 976us/step - loss: 0.0099
# Epoch 14/50
# 16/16 [==============================] - 0s 911us/step - loss: 0.0089
# Epoch 15/50
# 16/16 [==============================] - 0s 943us/step - loss: 0.0095
# Epoch 16/50
# 16/16 [==============================] - 0s 992us/step - loss: 0.0093
# Epoch 17/50
# 16/16 [==============================] - 0s 954us/step - loss: 0.0095
# Epoch 18/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 19/50
# 16/16 [==============================] - 0s 962us/step - loss: 0.0090
# Epoch 20/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 21/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 22/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 23/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 24/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 25/50
# 16/16 [==============================] - 0s 999us/step - loss: 0.0095
# Epoch 26/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 27/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 28/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 29/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 30/50
# 16/16 [==============================] - 0s 928us/step - loss: 0.0089
# Epoch 31/50
# 16/16 [==============================] - 0s 957us/step - loss: 0.0092
# Epoch 32/50
# 16/16 [==============================] - 0s 995us/step - loss: 0.0093
# Epoch 33/50
# 16/16 [==============================] - 0s 895us/step - loss: 0.0090
# Epoch 34/50
# 16/16 [==============================] - 0s 877us/step - loss: 0.0092
# Epoch 35/50
# 16/16 [==============================] - 0s 866us/step - loss: 0.0093
# Epoch 36/50
# 16/16 [==============================] - 0s 804us/step - loss: 0.0091
# Epoch 37/50
# 16/16 [==============================] - 0s 925us/step - loss: 0.0091
# Epoch 38/50
# 16/16 [==============================] - 0s 831us/step - loss: 0.0091
# Epoch 39/50
# 16/16 [==============================] - 0s 772us/step - loss: 0.0093
# Epoch 40/50
# 16/16 [==============================] - 0s 810us/step - loss: 0.0089
# Epoch 41/50
# 16/16 [==============================] - 0s 902us/step - loss: 0.0092
# Epoch 42/50
# 16/16 [==============================] - 0s 901us/step - loss: 0.0093
# Epoch 43/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 44/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 45/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0095
# Epoch 46/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 47/50
# 16/16 [==============================] - 0s 989us/step - loss: 0.0090
# Epoch 48/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 49/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 50/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0093
# 4/4 [==============================] - 0s 980us/step - loss: 0.0098
# loss : 0.009836149401962757

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import random

# 1. 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='rmsprop', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot